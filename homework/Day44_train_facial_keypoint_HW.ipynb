# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
# import tensorflow as tf
# print(tf.__version__)

# import os
# from google.colab import drive 
# drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# %cd 'gdrive/My Drive'
# os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
# %cd cupoy_cv_part4 # 可以自己改路徑

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = '../D42/training/training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Out:
# Using TensorFlow backend.
# C:\Users\1903012\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\1903012\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\1903012\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\1903012\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\1903012\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\1903012\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\1903012\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\1903012\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\1903012\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\1903012\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\1903012\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\1903012\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# WARNING:tensorflow:From C:\Users\1903012\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
# 印出網路結構
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# WARNING:tensorflow:From C:\Users\1903012\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 1712 samples, validate on 428 samples
# Epoch 1/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 0.0075 - val_loss: 0.0023
#
# Epoch 00001: val_loss improved from inf to 0.00230, saving model to best_weights.h5
# Epoch 2/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 0.0019 - val_loss: 0.0019
#
# Epoch 00002: val_loss improved from 0.00230 to 0.00191, saving model to best_weights.h5
# Epoch 3/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 0.0014 - val_loss: 0.0019
#
# Epoch 00003: val_loss improved from 0.00191 to 0.00186, saving model to best_weights.h5
# Epoch 4/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 0.0012 - val_loss: 0.0019
#
# Epoch 00004: val_loss did not improve from 0.00186
# Epoch 5/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 0.0012 - val_loss: 0.0019
#
# Epoch 00005: val_loss did not improve from 0.00186
# Epoch 6/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 0.0011 - val_loss: 0.0019
#
# Epoch 00006: val_loss improved from 0.00186 to 0.00186, saving model to best_weights.h5
# Epoch 7/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 0.0010 - val_loss: 0.0019
#
# Epoch 00007: val_loss improved from 0.00186 to 0.00185, saving model to best_weights.h5
# Epoch 8/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 9.2373e-04 - val_loss: 0.0017
#
# Epoch 00008: val_loss improved from 0.00185 to 0.00169, saving model to best_weights.h5
# Epoch 9/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 7.9203e-04 - val_loss: 0.0015
#
# Epoch 00009: val_loss improved from 0.00169 to 0.00148, saving model to best_weights.h5
# Epoch 10/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 6.9226e-04 - val_loss: 0.0014
#
# Epoch 00010: val_loss improved from 0.00148 to 0.00140, saving model to best_weights.h5
# Epoch 11/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 6.1861e-04 - val_loss: 0.0013
#
# Epoch 00011: val_loss improved from 0.00140 to 0.00129, saving model to best_weights.h5
# Epoch 12/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 5.5703e-04 - val_loss: 0.0012
#
# Epoch 00012: val_loss improved from 0.00129 to 0.00119, saving model to best_weights.h5
# Epoch 13/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 5.1651e-04 - val_loss: 0.0011
#
# Epoch 00013: val_loss improved from 0.00119 to 0.00108, saving model to best_weights.h5
# Epoch 14/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 4.8070e-04 - val_loss: 0.0010
#
# Epoch 00014: val_loss improved from 0.00108 to 0.00104, saving model to best_weights.h5
# Epoch 15/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 4.5089e-04 - val_loss: 9.9418e-04
#
# Epoch 00015: val_loss improved from 0.00104 to 0.00099, saving model to best_weights.h5
# Epoch 16/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 4.1994e-04 - val_loss: 9.6402e-04
#
# Epoch 00016: val_loss improved from 0.00099 to 0.00096, saving model to best_weights.h5
# Epoch 17/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 4.1287e-04 - val_loss: 9.4964e-04
#
# Epoch 00017: val_loss improved from 0.00096 to 0.00095, saving model to best_weights.h5
# Epoch 18/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 4.0625e-04 - val_loss: 9.6155e-04
#
# Epoch 00018: val_loss did not improve from 0.00095
# Epoch 19/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 3.8116e-04 - val_loss: 9.2726e-04
#
# Epoch 00019: val_loss improved from 0.00095 to 0.00093, saving model to best_weights.h5
# Epoch 20/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 3.7411e-04 - val_loss: 9.2702e-04
#
# Epoch 00020: val_loss improved from 0.00093 to 0.00093, saving model to best_weights.h5
# Epoch 21/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 3.4913e-04 - val_loss: 8.8165e-04
#
# Epoch 00021: val_loss improved from 0.00093 to 0.00088, saving model to best_weights.h5
# Epoch 22/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 3.3540e-04 - val_loss: 8.4885e-04
#
# Epoch 00022: val_loss improved from 0.00088 to 0.00085, saving model to best_weights.h5
# Epoch 23/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 3.2300e-04 - val_loss: 8.9257e-04
#
# Epoch 00023: val_loss did not improve from 0.00085
# Epoch 24/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 3.1540e-04 - val_loss: 8.3713e-04
#
# Epoch 00024: val_loss improved from 0.00085 to 0.00084, saving model to best_weights.h5
# Epoch 25/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 3.0983e-04 - val_loss: 8.0475e-04
#
# Epoch 00025: val_loss improved from 0.00084 to 0.00080, saving model to best_weights.h5
# Epoch 26/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 3.0957e-04 - val_loss: 8.6386e-04
#
# Epoch 00026: val_loss did not improve from 0.00080
# Epoch 27/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 3.0341e-04 - val_loss: 8.4394e-04
#
# Epoch 00027: val_loss did not improve from 0.00080
# Epoch 28/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.8252e-04 - val_loss: 8.3618e-04
#
# Epoch 00028: val_loss did not improve from 0.00080
# Epoch 29/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.8021e-04 - val_loss: 8.1094e-04
#
# Epoch 00029: val_loss did not improve from 0.00080
# Epoch 30/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.7170e-04 - val_loss: 7.8466e-04
#
# Epoch 00030: val_loss improved from 0.00080 to 0.00078, saving model to best_weights.h5
# Epoch 31/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.6855e-04 - val_loss: 7.8977e-04
#
# Epoch 00031: val_loss did not improve from 0.00078
# Epoch 32/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.6970e-04 - val_loss: 8.2072e-04
#
# Epoch 00032: val_loss did not improve from 0.00078
# Epoch 33/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.5702e-04 - val_loss: 8.2448e-04
#
# Epoch 00033: val_loss did not improve from 0.00078
# Epoch 34/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.5624e-04 - val_loss: 7.8049e-04
#
# Epoch 00034: val_loss improved from 0.00078 to 0.00078, saving model to best_weights.h5
# Epoch 35/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.4914e-04 - val_loss: 7.6185e-04
#
# Epoch 00035: val_loss improved from 0.00078 to 0.00076, saving model to best_weights.h5
# Epoch 36/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.4074e-04 - val_loss: 8.0257e-04
#
# Epoch 00036: val_loss did not improve from 0.00076
# Epoch 37/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.4322e-04 - val_loss: 7.6998e-04
#
# Epoch 00037: val_loss did not improve from 0.00076
# Epoch 38/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.3848e-04 - val_loss: 8.2126e-04
#
# Epoch 00038: val_loss did not improve from 0.00076
# Epoch 39/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.3447e-04 - val_loss: 7.7702e-04
#
# Epoch 00039: val_loss did not improve from 0.00076
# Epoch 40/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.2599e-04 - val_loss: 7.4282e-04
#
# Epoch 00040: val_loss improved from 0.00076 to 0.00074, saving model to best_weights.h5
# Epoch 41/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.2619e-04 - val_loss: 7.4891e-04
#
# Epoch 00041: val_loss did not improve from 0.00074
# Epoch 42/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.2557e-04 - val_loss: 8.0021e-04
#
# Epoch 00042: val_loss did not improve from 0.00074
# Epoch 43/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.1501e-04 - val_loss: 7.9564e-04
#
# Epoch 00043: val_loss did not improve from 0.00074
# Epoch 44/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.1008e-04 - val_loss: 7.8467e-04
#
# Epoch 00044: val_loss did not improve from 0.00074
# Epoch 45/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.1493e-04 - val_loss: 7.8719e-04
#
# Epoch 00045: val_loss did not improve from 0.00074
# Epoch 46/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.1014e-04 - val_loss: 7.6837e-04
#
# Epoch 00046: val_loss did not improve from 0.00074
# Epoch 47/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.0246e-04 - val_loss: 7.9297e-04
#
# Epoch 00047: val_loss did not improve from 0.00074
# Epoch 48/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.9768e-04 - val_loss: 7.6448e-04
#
# Epoch 00048: val_loss did not improve from 0.00074
# Epoch 49/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.9814e-04 - val_loss: 7.8429e-04
#
# Epoch 00049: val_loss did not improve from 0.00074
# Epoch 50/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.0206e-04 - val_loss: 7.5676e-04
#
# Epoch 00050: val_loss did not improve from 0.00074
# Epoch 51/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.9585e-04 - val_loss: 7.7797e-04
#
# Epoch 00051: val_loss did not improve from 0.00074
# Epoch 52/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.9183e-04 - val_loss: 7.8307e-04
#
# Epoch 00052: val_loss did not improve from 0.00074
# Epoch 53/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.9280e-04 - val_loss: 7.9446e-04
#
# Epoch 00053: val_loss did not improve from 0.00074
# Epoch 54/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.8610e-04 - val_loss: 7.4976e-04
#
# Epoch 00054: val_loss did not improve from 0.00074
# Epoch 55/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.8180e-04 - val_loss: 7.8228e-04
#
# Epoch 00055: val_loss did not improve from 0.00074
# Epoch 56/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.8059e-04 - val_loss: 7.6290e-04
#
# Epoch 00056: val_loss did not improve from 0.00074
# Epoch 57/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.7934e-04 - val_loss: 7.3625e-04
#
# Epoch 00057: val_loss improved from 0.00074 to 0.00074, saving model to best_weights.h5
# Epoch 58/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.8243e-04 - val_loss: 7.5635e-04
#
# Epoch 00058: val_loss did not improve from 0.00074
# Epoch 59/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.7396e-04 - val_loss: 7.7224e-04
#
# Epoch 00059: val_loss did not improve from 0.00074
# Epoch 60/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.7719e-04 - val_loss: 7.7833e-04
#
# Epoch 00060: val_loss did not improve from 0.00074
# Epoch 61/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.7139e-04 - val_loss: 7.7725e-04
#
# Epoch 00061: val_loss did not improve from 0.00074
# Epoch 62/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.6961e-04 - val_loss: 7.7317e-04
#
# Epoch 00062: val_loss did not improve from 0.00074
# Epoch 63/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.6501e-04 - val_loss: 7.5888e-04
#
# Epoch 00063: val_loss did not improve from 0.00074
# Epoch 64/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.7239e-04 - val_loss: 7.8908e-04
#
# Epoch 00064: val_loss did not improve from 0.00074
# Epoch 65/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.6941e-04 - val_loss: 7.5610e-04
#
# Epoch 00065: val_loss did not improve from 0.00074
# Epoch 66/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.6461e-04 - val_loss: 7.3933e-04
#
# Epoch 00066: val_loss did not improve from 0.00074
# Epoch 67/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.6731e-04 - val_loss: 7.6887e-04
#
# Epoch 00067: val_loss did not improve from 0.00074
# Epoch 68/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.5424e-04 - val_loss: 7.6919e-04
#
# Epoch 00068: val_loss did not improve from 0.00074
# Epoch 69/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.5995e-04 - val_loss: 7.6268e-04
#
# Epoch 00069: val_loss did not improve from 0.00074
# Epoch 70/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.5788e-04 - val_loss: 7.8354e-04
#
# Epoch 00070: val_loss did not improve from 0.00074
# Epoch 71/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.5383e-04 - val_loss: 7.5647e-04
#
# Epoch 00071: val_loss did not improve from 0.00074
# Epoch 72/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.5285e-04 - val_loss: 7.5371e-04
#
# Epoch 00072: val_loss did not improve from 0.00074
# Epoch 73/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.5293e-04 - val_loss: 7.2917e-04
#
# Epoch 00073: val_loss improved from 0.00074 to 0.00073, saving model to best_weights.h5
# Epoch 74/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.5104e-04 - val_loss: 7.4130e-04
#
# Epoch 00074: val_loss did not improve from 0.00073
# Epoch 75/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.4908e-04 - val_loss: 7.6467e-04
#
# Epoch 00075: val_loss did not improve from 0.00073
# Epoch 76/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.4592e-04 - val_loss: 7.4004e-04
#
# Epoch 00076: val_loss did not improve from 0.00073
# Epoch 77/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.4327e-04 - val_loss: 7.4945e-04
#
# Epoch 00077: val_loss did not improve from 0.00073
# Epoch 78/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.4804e-04 - val_loss: 7.7299e-04
#
# Epoch 00078: val_loss did not improve from 0.00073
# Epoch 79/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.4556e-04 - val_loss: 7.6813e-04
#
# Epoch 00079: val_loss did not improve from 0.00073
# Epoch 80/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.4137e-04 - val_loss: 7.7808e-04
#
# Epoch 00080: val_loss did not improve from 0.00073
# Epoch 81/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.4192e-04 - val_loss: 7.4577e-04
#
# Epoch 00081: val_loss did not improve from 0.00073
# Epoch 82/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.4223e-04 - val_loss: 7.5121e-04
#
# Epoch 00082: val_loss did not improve from 0.00073
# Epoch 83/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.4053e-04 - val_loss: 7.4665e-04
#
# Epoch 00083: val_loss did not improve from 0.00073
# Epoch 84/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.3982e-04 - val_loss: 7.6928e-04
#
# Epoch 00084: val_loss did not improve from 0.00073
# Epoch 85/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.3788e-04 - val_loss: 7.4893e-04
#
# Epoch 00085: val_loss did not improve from 0.00073
# Epoch 86/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.3629e-04 - val_loss: 7.4026e-04
#
# Epoch 00086: val_loss did not improve from 0.00073
# Epoch 87/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.3322e-04 - val_loss: 7.2314e-04
#
# Epoch 00087: val_loss improved from 0.00073 to 0.00072, saving model to best_weights.h5
# Epoch 88/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.3606e-04 - val_loss: 7.5058e-04
#
# Epoch 00088: val_loss did not improve from 0.00072
# Epoch 89/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.3318e-04 - val_loss: 7.5913e-04
#
# Epoch 00089: val_loss did not improve from 0.00072
# Epoch 90/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.3114e-04 - val_loss: 7.4884e-04
#
# Epoch 00090: val_loss did not improve from 0.00072
# Epoch 91/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.3235e-04 - val_loss: 7.4807e-04
#
# Epoch 00091: val_loss did not improve from 0.00072
# Epoch 92/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.3180e-04 - val_loss: 7.3433e-04
#
# Epoch 00092: val_loss did not improve from 0.00072
# Epoch 93/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.2721e-04 - val_loss: 7.3807e-04
#
# Epoch 00093: val_loss did not improve from 0.00072
# Epoch 94/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.2979e-04 - val_loss: 7.6833e-04
#
# Epoch 00094: val_loss did not improve from 0.00072
# Epoch 95/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.2710e-04 - val_loss: 7.8048e-04
#
# Epoch 00095: val_loss did not improve from 0.00072
# Epoch 96/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.2761e-04 - val_loss: 7.4056e-04
#
# Epoch 00096: val_loss did not improve from 0.00072
# Epoch 97/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.2559e-04 - val_loss: 7.4992e-04
#
# Epoch 00097: val_loss did not improve from 0.00072
# Epoch 98/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.2450e-04 - val_loss: 7.2543e-04
#
# Epoch 00098: val_loss did not improve from 0.00072
# Epoch 99/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.2530e-04 - val_loss: 7.6112e-04
#
# Epoch 00099: val_loss did not improve from 0.00072
# Epoch 100/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.2640e-04 - val_loss: 7.5871e-04
#
# Epoch 00100: val_loss did not improve from 0.00072
# Epoch 101/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.2142e-04 - val_loss: 7.6557e-04
#
# Epoch 00101: val_loss did not improve from 0.00072
# Epoch 102/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.2035e-04 - val_loss: 7.6589e-04
#
# Epoch 00102: val_loss did not improve from 0.00072
# Epoch 103/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.1929e-04 - val_loss: 7.5755e-04
#
# Epoch 00103: val_loss did not improve from 0.00072
# Epoch 104/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.1874e-04 - val_loss: 7.4458e-04
#
# Epoch 00104: val_loss did not improve from 0.00072
# Epoch 105/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.1894e-04 - val_loss: 7.6049e-04
#
# Epoch 00105: val_loss did not improve from 0.00072
# Epoch 106/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.1717e-04 - val_loss: 7.5236e-04
#
# Epoch 00106: val_loss did not improve from 0.00072
# Epoch 107/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.1713e-04 - val_loss: 7.4764e-04
#
# Epoch 00107: val_loss did not improve from 0.00072
# Epoch 108/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.1515e-04 - val_loss: 7.5321e-04
#
# Epoch 00108: val_loss did not improve from 0.00072
# Epoch 109/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.1483e-04 - val_loss: 7.4656e-04
#
# Epoch 00109: val_loss did not improve from 0.00072
# Epoch 110/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.1256e-04 - val_loss: 7.3486e-04
#
# Epoch 00110: val_loss did not improve from 0.00072
# Epoch 111/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.1362e-04 - val_loss: 7.6108e-04
#
# Epoch 00111: val_loss did not improve from 0.00072
# Epoch 112/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.1651e-04 - val_loss: 7.7498e-04
#
# Epoch 00112: val_loss did not improve from 0.00072
# Epoch 113/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.1224e-04 - val_loss: 7.8817e-04
#
# Epoch 00113: val_loss did not improve from 0.00072
# Epoch 114/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.1211e-04 - val_loss: 7.5147e-04
#
# Epoch 00114: val_loss did not improve from 0.00072
# Epoch 115/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.1250e-04 - val_loss: 7.5391e-04
#
# Epoch 00115: val_loss did not improve from 0.00072
# Epoch 116/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.0974e-04 - val_loss: 7.6222e-04
#
# Epoch 00116: val_loss did not improve from 0.00072
# Epoch 117/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.0947e-04 - val_loss: 7.6728e-04
#
# Epoch 00117: val_loss did not improve from 0.00072
# Epoch 118/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.0937e-04 - val_loss: 7.5337e-04
#
# Epoch 00118: val_loss did not improve from 0.00072
# Epoch 119/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.0591e-04 - val_loss: 7.8632e-04
#
# Epoch 00119: val_loss did not improve from 0.00072
# Epoch 120/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.1364e-04 - val_loss: 7.4599e-04
#
# Epoch 00120: val_loss did not improve from 0.00072
# Epoch 121/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.1001e-04 - val_loss: 7.3711e-04
#
# Epoch 00121: val_loss did not improve from 0.00072
# Epoch 122/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.0850e-04 - val_loss: 7.8634e-04
#
# Epoch 00122: val_loss did not improve from 0.00072
# Epoch 123/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.0721e-04 - val_loss: 8.0931e-04
#
# Epoch 00123: val_loss did not improve from 0.00072
# Epoch 124/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.0559e-04 - val_loss: 7.4651e-04
#
# Epoch 00124: val_loss did not improve from 0.00072
# Epoch 125/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.0748e-04 - val_loss: 7.5854e-04
#
# Epoch 00125: val_loss did not improve from 0.00072
# Epoch 126/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.0394e-04 - val_loss: 7.7031e-04
#
# Epoch 00126: val_loss did not improve from 0.00072
# Epoch 127/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.0318e-04 - val_loss: 7.8534e-04
#
# Epoch 00127: val_loss did not improve from 0.00072
# Epoch 128/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.0588e-04 - val_loss: 7.6740e-04
#
# Epoch 00128: val_loss did not improve from 0.00072
# Epoch 129/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.0329e-04 - val_loss: 7.6165e-04
#
# Epoch 00129: val_loss did not improve from 0.00072
# Epoch 130/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.0134e-04 - val_loss: 7.4994e-04
#
# Epoch 00130: val_loss did not improve from 0.00072
# Epoch 131/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.0168e-04 - val_loss: 7.6281e-04
#
# Epoch 00131: val_loss did not improve from 0.00072
# Epoch 132/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.0142e-04 - val_loss: 7.5453e-04
#
# Epoch 00132: val_loss did not improve from 0.00072
# Epoch 133/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.0178e-04 - val_loss: 7.6298e-04
#
# Epoch 00133: val_loss did not improve from 0.00072
# Epoch 134/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.0024e-04 - val_loss: 7.8523e-04
#
# Epoch 00134: val_loss did not improve from 0.00072
# Epoch 135/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 9.7912e-05 - val_loss: 7.4872e-04
#
# Epoch 00135: val_loss did not improve from 0.00072
# Epoch 136/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 9.9837e-05 - val_loss: 7.6331e-04
#
# Epoch 00136: val_loss did not improve from 0.00072
# Epoch 137/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 9.7783e-05 - val_loss: 7.7557e-04
#
# Epoch 00137: val_loss did not improve from 0.00072
# Epoch 138/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 9.9853e-05 - val_loss: 7.7736e-04
#
# Epoch 00138: val_loss did not improve from 0.00072
# Epoch 139/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 9.9095e-05 - val_loss: 7.6509e-04
#
# Epoch 00139: val_loss did not improve from 0.00072
# Epoch 140/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.7248e-05 - val_loss: 7.5909e-04
#
# Epoch 00140: val_loss did not improve from 0.00072
# Epoch 141/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.6745e-05 - val_loss: 7.5406e-04
#
# Epoch 00141: val_loss did not improve from 0.00072
# Epoch 142/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.5701e-05 - val_loss: 7.5098e-04
#
# Epoch 00142: val_loss did not improve from 0.00072
# Epoch 143/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 9.6326e-05 - val_loss: 7.6475e-04
#
# Epoch 00143: val_loss did not improve from 0.00072
# Epoch 144/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 9.2762e-05 - val_loss: 7.7942e-04
#
# Epoch 00144: val_loss did not improve from 0.00072
# Epoch 145/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 9.2839e-05 - val_loss: 7.6646e-04
#
# Epoch 00145: val_loss did not improve from 0.00072
# Epoch 146/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 9.5166e-05 - val_loss: 7.8040e-04
#
# Epoch 00146: val_loss did not improve from 0.00072
# Epoch 147/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 9.6754e-05 - val_loss: 7.7701e-04
#
# Epoch 00147: val_loss did not improve from 0.00072
# Epoch 148/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 9.6233e-05 - val_loss: 7.2041e-04
#
# Epoch 00148: val_loss improved from 0.00072 to 0.00072, saving model to best_weights.h5
# Epoch 149/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 9.1985e-05 - val_loss: 7.4725e-04
#
# Epoch 00149: val_loss did not improve from 0.00072
# Epoch 150/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 9.3360e-05 - val_loss: 7.7053e-04
#
# Epoch 00150: val_loss did not improve from 0.00072

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = '../D42/test/test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# %%
# 實現圖片以及關機點 label 做左右翻轉的函數
def augment_data(img, points):
    rows, cols = img.shape
    new_img = np.copy(img)
    
    # 翻轉圖片
    for i in range(96):
        for j in range(48):
            temp = img[i][j]
            new_img[i][j] = img[i][cols-j-1]
            new_img[i][cols-j-1] = temp
            
    # 翻轉關鍵點 label
    new_points = np.copy(points)
    for i in range(0,30,2):
        new_points[i] = -points[i]
    
    # 調整對稱的 label
    new_points_temp = np.copy(new_points)
    new_points[0:2] = new_points_temp[2:4]
    new_points[2:4] = new_points_temp[0:2]
    new_points[4:6] = new_points_temp[8:10]
    new_points[6:8] = new_points_temp[10:12]
    new_points[8:10] = new_points_temp[4:6]
    new_points[10:12] = new_points_temp[6:8]
    new_points[12:14] = new_points_temp[16:18]
    new_points[14:16] = new_points_temp[18:20]
    new_points[16:18] = new_points_temp[12:14]
    new_points[18:20] = new_points_temp[14:16]
    new_points[22:24] = new_points_temp[24:26]
    new_points[24:26] = new_points_temp[22:24]
        
    return new_img, new_points

# %%
flip_img, flip_points = augment_data(imgs_train[0], points_train[0])

fig = plt.figure()
ax = fig.add_subplot(1, 2, 1, xticks=[], yticks=[])
plot_keypoints(imgs_train[0], points_train[0]) # 原來的圖片
ax = fig.add_subplot(1, 2, 2, xticks=[], yticks=[])
plot_keypoints(flip_img, flip_points) # 翻轉後的圖片

# %%
# 創建 list
aug_imgs_train = []
aug_points_train = []

# 對所有原始資料做 augmentation
for i in range(imgs_train.shape[0]):
    # 做左右翻轉
    aug_img, aug_point = augment_data(imgs_train[i], points_train[i])
    
    # append 原始資料
    aug_imgs_train.append(imgs_train[i])
    aug_points_train.append(points_train[i]) 
    
    # append 做過 augmentation 後的資料
    aug_imgs_train.append(aug_img)
    aug_points_train.append(aug_point) 

# convert to numpy
aug_imgs_train = np.array(aug_imgs_train)   
aug_points_train = np.copy(aug_points_train)

print(aug_imgs_train.shape)
print(aug_points_train.shape)
# Out:
# (4280, 96, 96)
# (4280, 30)

# %%
# model checkpoint 
checkpoint_aug = ModelCheckpoint('best_weights_augment.h5', verbose=1, save_best_only=True)
# training the model
hist_model_aug = model_with_augment.fit(aug_imgs_train.reshape(aug_imgs_train.shape[0], 96, 96, 1), aug_points_train, 
                           validation_split=0.2, batch_size=64, callbacks=[checkpoint_aug, hist],
                           shuffle=True, epochs=150, verbose=1)
# Out:
# Train on 3424 samples, validate on 856 samples
# Epoch 1/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 0.0044 - val_loss: 0.0019
#
# Epoch 00001: val_loss improved from inf to 0.00187, saving model to best_weights_augment.h5
# Epoch 2/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 0.0013 - val_loss: 0.0019
#
# Epoch 00002: val_loss did not improve from 0.00187
# Epoch 3/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 0.0011 - val_loss: 0.0018
#
# Epoch 00003: val_loss improved from 0.00187 to 0.00178, saving model to best_weights_augment.h5
# Epoch 4/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 9.1401e-04 - val_loss: 0.0016
#
# Epoch 00004: val_loss improved from 0.00178 to 0.00165, saving model to best_weights_augment.h5
# Epoch 5/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 6.8778e-04 - val_loss: 0.0012
#
# Epoch 00005: val_loss improved from 0.00165 to 0.00125, saving model to best_weights_augment.h5
# Epoch 6/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 5.8014e-04 - val_loss: 0.0011
#
# Epoch 00006: val_loss improved from 0.00125 to 0.00111, saving model to best_weights_augment.h5
# Epoch 7/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 4.8458e-04 - val_loss: 9.7323e-04
#
# Epoch 00007: val_loss improved from 0.00111 to 0.00097, saving model to best_weights_augment.h5
# Epoch 8/150
# 3424/3424 [==============================] - 15s 4ms/step - loss: 4.4692e-04 - val_loss: 9.1642e-04
#
# Epoch 00008: val_loss improved from 0.00097 to 0.00092, saving model to best_weights_augment.h5
# Epoch 9/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 4.0238e-04 - val_loss: 8.2204e-04
#
# Epoch 00009: val_loss improved from 0.00092 to 0.00082, saving model to best_weights_augment.h5
# Epoch 10/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 3.6878e-04 - val_loss: 7.6507e-04
#
# Epoch 00010: val_loss improved from 0.00082 to 0.00077, saving model to best_weights_augment.h5
# Epoch 11/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 3.4246e-04 - val_loss: 7.9154e-04
#
# Epoch 00011: val_loss did not improve from 0.00077
# Epoch 12/150
# 3424/3424 [==============================] - 14s 4ms/step - loss: 3.2601e-04 - val_loss: 7.4572e-04
#
# Epoch 00012: val_loss improved from 0.00077 to 0.00075, saving model to best_weights_augment.h5
# Epoch 13/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 3.1100e-04 - val_loss: 7.1559e-04
#
# Epoch 00013: val_loss improved from 0.00075 to 0.00072, saving model to best_weights_augment.h5
# Epoch 14/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 2.9771e-04 - val_loss: 6.8793e-04
#
# Epoch 00014: val_loss improved from 0.00072 to 0.00069, saving model to best_weights_augment.h5
# Epoch 15/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 2.8346e-04 - val_loss: 6.9336e-04
#
# Epoch 00015: val_loss did not improve from 0.00069
# Epoch 16/150
# 3424/3424 [==============================] - 15s 4ms/step - loss: 2.6893e-04 - val_loss: 6.9655e-04
#
# Epoch 00016: val_loss did not improve from 0.00069
# Epoch 17/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 2.6624e-04 - val_loss: 6.5157e-04
#
# Epoch 00017: val_loss improved from 0.00069 to 0.00065, saving model to best_weights_augment.h5
# Epoch 18/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 2.5778e-04 - val_loss: 6.6941e-04
#
# Epoch 00018: val_loss did not improve from 0.00065
# Epoch 19/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 2.4894e-04 - val_loss: 7.0024e-04
#
# Epoch 00019: val_loss did not improve from 0.00065
# Epoch 20/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 2.4252e-04 - val_loss: 6.7935e-04
#
# Epoch 00020: val_loss did not improve from 0.00065
# Epoch 21/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 2.3209e-04 - val_loss: 7.8096e-04
#
# Epoch 00021: val_loss did not improve from 0.00065
# Epoch 22/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 2.2802e-04 - val_loss: 6.3341e-04
#
# Epoch 00022: val_loss improved from 0.00065 to 0.00063, saving model to best_weights_augment.h5
# Epoch 23/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 2.1992e-04 - val_loss: 6.7885e-04
#
# Epoch 00023: val_loss did not improve from 0.00063
# Epoch 24/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 2.1614e-04 - val_loss: 6.2388e-04
#
# Epoch 00024: val_loss improved from 0.00063 to 0.00062, saving model to best_weights_augment.h5
# Epoch 25/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 2.1094e-04 - val_loss: 6.9322e-04
#
# Epoch 00025: val_loss did not improve from 0.00062
# Epoch 26/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 2.0837e-04 - val_loss: 6.7992e-04
#
# Epoch 00026: val_loss did not improve from 0.00062
# Epoch 27/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 2.0587e-04 - val_loss: 6.3920e-04
#
# Epoch 00027: val_loss did not improve from 0.00062
# Epoch 28/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.9823e-04 - val_loss: 6.5899e-04
#
# Epoch 00028: val_loss did not improve from 0.00062
# Epoch 29/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.9910e-04 - val_loss: 6.3849e-04
#
# Epoch 00029: val_loss did not improve from 0.00062
# Epoch 30/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.9260e-04 - val_loss: 6.5262e-04
#
# Epoch 00030: val_loss did not improve from 0.00062
# Epoch 31/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.8806e-04 - val_loss: 6.2856e-04
#
# Epoch 00031: val_loss did not improve from 0.00062
# Epoch 32/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.8375e-04 - val_loss: 6.4474e-04
#
# Epoch 00032: val_loss did not improve from 0.00062
# Epoch 33/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.8334e-04 - val_loss: 6.0123e-04
#
# Epoch 00033: val_loss improved from 0.00062 to 0.00060, saving model to best_weights_augment.h5
# Epoch 34/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.7424e-04 - val_loss: 6.2729e-04
#
# Epoch 00034: val_loss did not improve from 0.00060
# Epoch 35/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.7356e-04 - val_loss: 6.1683e-04
#
# Epoch 00035: val_loss did not improve from 0.00060
# Epoch 36/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.7338e-04 - val_loss: 6.3069e-04
#
# Epoch 00036: val_loss did not improve from 0.00060
# Epoch 37/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.6855e-04 - val_loss: 6.4789e-04
#
# Epoch 00037: val_loss did not improve from 0.00060
# Epoch 38/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.6942e-04 - val_loss: 6.1620e-04
#
# Epoch 00038: val_loss did not improve from 0.00060
# Epoch 39/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.6358e-04 - val_loss: 6.0668e-04
#
# Epoch 00039: val_loss did not improve from 0.00060
# Epoch 40/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.5984e-04 - val_loss: 6.3878e-04
#
# Epoch 00040: val_loss did not improve from 0.00060
# Epoch 41/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 1.5916e-04 - val_loss: 6.5633e-04
#
# Epoch 00041: val_loss did not improve from 0.00060
# Epoch 42/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.5720e-04 - val_loss: 6.6928e-04
#
# Epoch 00042: val_loss did not improve from 0.00060
# Epoch 43/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 1.5437e-04 - val_loss: 6.2506e-04
#
# Epoch 00043: val_loss did not improve from 0.00060
# Epoch 44/150
# 3424/3424 [==============================] - 12s 4ms/step - loss: 1.5536e-04 - val_loss: 6.2652e-04
#
# Epoch 00044: val_loss did not improve from 0.00060
# Epoch 45/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 1.5017e-04 - val_loss: 6.3525e-04
#
# Epoch 00045: val_loss did not improve from 0.00060
# Epoch 46/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.5106e-04 - val_loss: 6.0499e-04
#
# Epoch 00046: val_loss did not improve from 0.00060
# Epoch 47/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.4718e-04 - val_loss: 6.2578e-04
#
# Epoch 00047: val_loss did not improve from 0.00060
# Epoch 48/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 1.4182e-04 - val_loss: 6.1104e-04
#
# Epoch 00048: val_loss did not improve from 0.00060
# Epoch 49/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.4327e-04 - val_loss: 6.5822e-04
#
# Epoch 00049: val_loss did not improve from 0.00060
# Epoch 50/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.3912e-04 - val_loss: 6.1213e-04
#
# Epoch 00050: val_loss did not improve from 0.00060
# Epoch 51/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.3786e-04 - val_loss: 6.2522e-04
#
# Epoch 00051: val_loss did not improve from 0.00060
# Epoch 52/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.3789e-04 - val_loss: 6.2617e-04
#
# Epoch 00052: val_loss did not improve from 0.00060
# Epoch 53/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 1.3226e-04 - val_loss: 6.2021e-04
#
# Epoch 00053: val_loss did not improve from 0.00060
# Epoch 54/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.3195e-04 - val_loss: 6.0191e-04
#
# Epoch 00054: val_loss did not improve from 0.00060
# Epoch 55/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.3177e-04 - val_loss: 6.4640e-04
#
# Epoch 00055: val_loss did not improve from 0.00060
# Epoch 56/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.2855e-04 - val_loss: 6.2885e-04
#
# Epoch 00056: val_loss did not improve from 0.00060
# Epoch 57/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.2766e-04 - val_loss: 6.5875e-04
#
# Epoch 00057: val_loss did not improve from 0.00060
# Epoch 58/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.2549e-04 - val_loss: 6.3153e-04
#
# Epoch 00058: val_loss did not improve from 0.00060
# Epoch 59/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.2481e-04 - val_loss: 6.7823e-04
#
# Epoch 00059: val_loss did not improve from 0.00060
# Epoch 60/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.2282e-04 - val_loss: 6.3548e-04
#
# Epoch 00060: val_loss did not improve from 0.00060
# Epoch 61/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.2289e-04 - val_loss: 6.2325e-04
#
# Epoch 00061: val_loss did not improve from 0.00060
# Epoch 62/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.2143e-04 - val_loss: 6.2351e-04
#
# Epoch 00062: val_loss did not improve from 0.00060
# Epoch 63/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.1881e-04 - val_loss: 6.3501e-04
#
# Epoch 00063: val_loss did not improve from 0.00060
# Epoch 64/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.1693e-04 - val_loss: 6.2495e-04
#
# Epoch 00064: val_loss did not improve from 0.00060
# Epoch 65/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.1856e-04 - val_loss: 6.5193e-04
#
# Epoch 00065: val_loss did not improve from 0.00060
# Epoch 66/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.1619e-04 - val_loss: 6.1966e-04
#
# Epoch 00066: val_loss did not improve from 0.00060
# Epoch 67/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.1433e-04 - val_loss: 6.1578e-04
#
# Epoch 00067: val_loss did not improve from 0.00060
# Epoch 68/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.1406e-04 - val_loss: 6.4401e-04
#
# Epoch 00068: val_loss did not improve from 0.00060
# Epoch 69/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.1444e-04 - val_loss: 6.1725e-04
#
# Epoch 00069: val_loss did not improve from 0.00060
# Epoch 70/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.0976e-04 - val_loss: 6.2280e-04
#
# Epoch 00070: val_loss did not improve from 0.00060
# Epoch 71/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.1031e-04 - val_loss: 6.4911e-04
#
# Epoch 00071: val_loss did not improve from 0.00060
# Epoch 72/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.0951e-04 - val_loss: 6.1799e-04
#
# Epoch 00072: val_loss did not improve from 0.00060
# Epoch 73/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.0720e-04 - val_loss: 6.4455e-04
#
# Epoch 00073: val_loss did not improve from 0.00060
# Epoch 74/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.1068e-04 - val_loss: 6.3219e-04
#
# Epoch 00074: val_loss did not improve from 0.00060
# Epoch 75/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.0460e-04 - val_loss: 6.4391e-04
#
# Epoch 00075: val_loss did not improve from 0.00060
# Epoch 76/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.0692e-04 - val_loss: 6.3089e-04
#
# Epoch 00076: val_loss did not improve from 0.00060
# Epoch 77/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.0488e-04 - val_loss: 6.3974e-04
#
# Epoch 00077: val_loss did not improve from 0.00060
# Epoch 78/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.0370e-04 - val_loss: 6.1200e-04
#
# Epoch 00078: val_loss did not improve from 0.00060
# Epoch 79/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.0372e-04 - val_loss: 6.3323e-04
#
# Epoch 00079: val_loss did not improve from 0.00060
# Epoch 80/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.0419e-04 - val_loss: 6.0865e-04
#
# Epoch 00080: val_loss did not improve from 0.00060
# Epoch 81/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.0316e-04 - val_loss: 6.1063e-04
#
# Epoch 00081: val_loss did not improve from 0.00060
# Epoch 82/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.0213e-04 - val_loss: 6.4514e-04
#
# Epoch 00082: val_loss did not improve from 0.00060
# Epoch 83/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 9.8987e-05 - val_loss: 6.2267e-04
#
# Epoch 00083: val_loss did not improve from 0.00060
# Epoch 84/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.0244e-04 - val_loss: 6.5329e-04
#
# Epoch 00084: val_loss did not improve from 0.00060
# Epoch 85/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 9.9775e-05 - val_loss: 6.1226e-04
#
# Epoch 00085: val_loss did not improve from 0.00060
# Epoch 86/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 9.7001e-05 - val_loss: 6.2323e-04
#
# Epoch 00086: val_loss did not improve from 0.00060
# Epoch 87/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 9.9186e-05 - val_loss: 6.3266e-04
#
# Epoch 00087: val_loss did not improve from 0.00060
# Epoch 88/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 9.7530e-05 - val_loss: 6.0816e-04
#
# Epoch 00088: val_loss did not improve from 0.00060
# Epoch 89/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 9.6333e-05 - val_loss: 6.2832e-04
#
# Epoch 00089: val_loss did not improve from 0.00060
# Epoch 90/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 9.5510e-05 - val_loss: 6.4900e-04
#
# Epoch 00090: val_loss did not improve from 0.00060
# Epoch 91/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 9.4249e-05 - val_loss: 6.0477e-04
#
# Epoch 00091: val_loss did not improve from 0.00060
# Epoch 92/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 9.5259e-05 - val_loss: 6.2818e-04
#
# Epoch 00092: val_loss did not improve from 0.00060
# Epoch 93/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 9.8148e-05 - val_loss: 6.3805e-04
#
# Epoch 00093: val_loss did not improve from 0.00060
# Epoch 94/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 9.5909e-05 - val_loss: 6.3575e-04
#
# Epoch 00094: val_loss did not improve from 0.00060
# Epoch 95/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 9.2692e-05 - val_loss: 6.4539e-04
#
# Epoch 00095: val_loss did not improve from 0.00060
# Epoch 96/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 9.3547e-05 - val_loss: 6.2209e-04
#
# Epoch 00096: val_loss did not improve from 0.00060
# Epoch 97/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 9.1677e-05 - val_loss: 6.3607e-04
#
# Epoch 00097: val_loss did not improve from 0.00060
# Epoch 98/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 9.2485e-05 - val_loss: 6.2135e-04
#
# Epoch 00098: val_loss did not improve from 0.00060
# Epoch 99/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 9.2843e-05 - val_loss: 6.3240e-04
#
# Epoch 00099: val_loss did not improve from 0.00060
# Epoch 100/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 9.1843e-05 - val_loss: 6.2852e-04
#
# Epoch 00100: val_loss did not improve from 0.00060
# Epoch 101/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 9.0514e-05 - val_loss: 6.3151e-04
#
# Epoch 00101: val_loss did not improve from 0.00060
# Epoch 102/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 8.9472e-05 - val_loss: 6.3339e-04
#
# Epoch 00102: val_loss did not improve from 0.00060
# Epoch 103/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 8.5850e-05 - val_loss: 6.3450e-04
#
# Epoch 00111: val_loss did not improve from 0.00060
# Epoch 112/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 8.5289e-05 - val_loss: 6.3402e-04
#
# Epoch 00112: val_loss did not improve from 0.00060
# Epoch 113/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 8.4174e-05 - val_loss: 6.3875e-04
#
# Epoch 00113: val_loss did not improve from 0.00060
# Epoch 114/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 8.7090e-05 - val_loss: 6.3694e-04
#
# Epoch 00114: val_loss did not improve from 0.00060
# Epoch 115/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 8.5985e-05 - val_loss: 6.4070e-04
#
# Epoch 00115: val_loss did not improve from 0.00060
# Epoch 116/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 8.6386e-05 - val_loss: 6.2467e-04
#
# Epoch 00116: val_loss did not improve from 0.00060
# Epoch 117/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 8.3463e-05 - val_loss: 6.2674e-04
#
# Epoch 00117: val_loss did not improve from 0.00060
# Epoch 118/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 8.3126e-05 - val_loss: 6.0783e-04
#
# Epoch 00118: val_loss did not improve from 0.00060
# Epoch 119/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 8.1862e-05 - val_loss: 6.4440e-04
#
# Epoch 00119: val_loss did not improve from 0.00060
# Epoch 120/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 8.3318e-05 - val_loss: 6.1465e-04
#
# Epoch 00120: val_loss did not improve from 0.00060
# Epoch 121/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 8.2808e-05 - val_loss: 6.1318e-04
#
# Epoch 00121: val_loss did not improve from 0.00060
# Epoch 122/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 8.4008e-05 - val_loss: 6.4041e-04
#
# Epoch 00122: val_loss did not improve from 0.00060
# Epoch 123/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 8.3737e-05 - val_loss: 6.1381e-04
#
# Epoch 00123: val_loss did not improve from 0.00060
# Epoch 124/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 8.2008e-05 - val_loss: 6.4069e-04
#
# Epoch 00124: val_loss did not improve from 0.00060
# Epoch 125/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 8.3387e-05 - val_loss: 6.1570e-04
#
# Epoch 00125: val_loss did not improve from 0.00060
# Epoch 126/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 8.3474e-05 - val_loss: 6.3015e-04
#
# Epoch 00126: val_loss did not improve from 0.00060
# Epoch 127/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 8.2096e-05 - val_loss: 6.3442e-04
#
# Epoch 00127: val_loss did not improve from 0.00060
# Epoch 128/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 8.1930e-05 - val_loss: 6.2723e-04
#
# Epoch 00128: val_loss did not improve from 0.00060
# Epoch 129/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 8.2429e-05 - val_loss: 6.3427e-04
#
# Epoch 00129: val_loss did not improve from 0.00060
# Epoch 130/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 8.5468e-05 - val_loss: 6.0779e-04
#
# Epoch 00130: val_loss did not improve from 0.00060
# Epoch 131/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 8.1450e-05 - val_loss: 6.4316e-04
#
# Epoch 00131: val_loss did not improve from 0.00060
# Epoch 132/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 7.8323e-05 - val_loss: 6.4052e-04
#
# Epoch 00132: val_loss did not improve from 0.00060
# Epoch 133/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 8.0249e-05 - val_loss: 6.2077e-04
#
# Epoch 00133: val_loss did not improve from 0.00060
# Epoch 134/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 7.9525e-05 - val_loss: 6.1941e-04
#
# Epoch 00134: val_loss did not improve from 0.00060
# Epoch 135/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 7.9394e-05 - val_loss: 6.2359e-04
#
# Epoch 00135: val_loss did not improve from 0.00060
# Epoch 136/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 7.7699e-05 - val_loss: 6.2416e-04
#
# Epoch 00136: val_loss did not improve from 0.00060
# Epoch 137/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 8.0152e-05 - val_loss: 6.2677e-04
#
# Epoch 00137: val_loss did not improve from 0.00060
# Epoch 138/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 7.9694e-05 - val_loss: 6.1267e-04
#
# Epoch 00138: val_loss did not improve from 0.00060
# Epoch 139/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 7.8257e-05 - val_loss: 6.2603e-04
#
# Epoch 00139: val_loss did not improve from 0.00060
# Epoch 140/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 7.7571e-05 - val_loss: 6.2778e-04
#
# Epoch 00140: val_loss did not improve from 0.00060
# Epoch 141/150
#  256/3424 [=>............................] - ETA: 9s - loss: 7.3036e-05
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model_aug.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model_aug.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')
